# %% [markdown]
# # Automated mesh extraction from .bin files
#
# This notebook will detail an approach to taking the .bin files containing all the meshes in a programatic way, avoiding the CloudCompare GUI.
#
# ## CC command line extraction
#
# The individual meshes can be extracted from the .bin files at the command line.
# The filename saving options aren't the most flexible around the extraction of the meshes.
#
# ## Extracting all meshes at once.
#
# Let's look first at extracting all the meshes to individual .ply files.
#
# I've placed the `park_row.bin` merged mesh file in the Pointcept home dir one above this one.

# %%
import subprocess
import os
import shutil

from pathlib import Path


cloudcompare_path = "org.cloudcompare.CloudCompare"
input_path = "/home/sogilvy/park_row.bin"
input_stem = "park_row.bin"

# Make a clean working dir for this test.
# Also copy the input file there
workdir = "./test_all_meshes"
if os.path.exists(workdir):
    shutil.rmtree(workdir)
os.makedirs(workdir)
new_path = Path(workdir) / input_stem
shutil.copy(input_path, str(new_path))

# Define the command-line arguments to run with CloudCompare
# Example: Loading a file and performing an operation
command = [
    cloudcompare_path,
    "-SILENT",  # Run in silent mode (no GUI)
    "-O", input_stem,  # Load a mesh file (replace with your file path)
    "-M_EXPORT_FMT", "PLY",  # Set output format to PLY
    "-NO_TIMESTAMP", "-SAVE_MESHES",
    ]

try:
    # Run the command as a subprocess
    result = subprocess.run(command, cwd=workdir, check=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Print the output and any errors
    print("CloudCompare output:", result.stdout.decode())
    print("CloudCompare errors:", result.stderr.decode())
except subprocess.CalledProcessError as e:
    # Handle errors if the subprocess fails
    print(f"CloudCompare failed with error: {e.stderr.decode()}")


output_dir = Path(workdir)
for file in output_dir.iterdir():
    print(file.name)
# Out:
# CloudCompare output: [18:59:48] [ccColorScalesManager] Found 0 custom scale(s) in persistent settings
# [18:59:48] [Plugin] Searching: /app/lib/cloudcompare/plugins
# [18:59:48] 	Plugin found: Python Plugin (libPythonRuntime.so)
# [18:59:48] 	Plugin found: 3DMASC (libQ3DMASC_PLUGIN.so)
# [18:59:48] 	Plugin found: Additional I/O (libQADDITIONAL_IO_PLUGIN.so)
# [18:59:48] 	Plugin found: Animation (libQANIMATION_PLUGIN.so)
# [18:59:48] 	Plugin found: AutoSeg (libQAUTO_SEG_PLUGIN.so)
# [18:59:48] 	Plugin found: CEA Virtual Broom (libQBROOM_PLUGIN.so)
# [18:59:48] 	Plugin found: CANUPO (libQCANUPO_PLUGIN.so)
# [18:59:48] 	Plugin found: Cloud layers (libQCLOUDLAYERS_PLUGIN.so)
# [18:59:48] 	Plugin found: Colorimetric Segmenter (libQCOLORIMETRIC_SEGMENTER_PLUGIN.so)
# [18:59:48] 	Plugin found: Compass (libQCOMPASS_PLUGIN.so)
# [18:59:48] 	Plugin found: Core I/O (libQCORE_IO_PLUGIN.so)
# [18:59:48] 	Plugin found: CSF Filter (libQCSF_PLUGIN.so)
# [18:59:48] 	Plugin found: CSV Matrix I/O (libQCSV_MATRIX_IO_PLUGIN.so)
# [18:59:48] 	Plugin found: E57 (libQE57_IO_PLUGIN.so)
# [18:59:48] 	Plugin found: EDL Shader (libQEDL_GL_PLUGIN.so)
# [18:59:48] 	Plugin found: Facet/fracture detection (libQFACETS_PLUGIN.so)
# [18:59:48] 	Plugin found: Hough Normals Computation (libQHOUGH_NORMALS_PLUGIN.so)
# [18:59:48] 	Plugin found: Hidden Point Removal (libQHPR_PLUGIN.so)
# [18:59:48] 	Plugin found: LAS (I/O Plugin) (libQLAS_IO_PLUGIN.so)
# [18:59:48] 	Plugin found: M3C2 Distance (libQM3C2_PLUGIN.so)
# [18:59:48] 	Plugin found: ManualSeg (libQMANUAL_SEG_PLUGIN.so)
# [18:59:48] 	Plugin found: MPlane (libQMPLANE_PLUGIN.so)
# [18:59:48] 	Plugin found: PCD file I/O (libQPCL_IO_PLUGIN.so)
# [18:59:48] 	Plugin found: PCL wrapper (libQPCL_PLUGIN.so)
# [18:59:48] 	Plugin found: PCV / ShadeVis (libQPCV_PLUGIN.so)
# [18:59:48] 	Plugin found: Photoscan I/O (libQPHOTOSCAN_IO_PLUGIN.so)
# [18:59:48] 	Plugin found: PoissonRecon (libQPOISSON_RECON_PLUGIN.so)
# [18:59:48] 	Plugin found: Surface of Revolution Analysis (libQSRA_PLUGIN.so)
# [18:59:48] 	Plugin found: SSAO Shader (libQSSAO_GL_PLUGIN.so)
# [18:59:48] 	Plugin found: TreeIso (libQTREEISO_PLUGIN.so)
# [18:59:48] [Plugin] Searching: /home/sogilvy/.var/app/org.cloudcompare.CloudCompare/data/CCCorp/CloudCompare/plugins
# [18:59:48] [Plugin] Searching: /app/share/CCCorp/CloudCompare/plugins
# [18:59:48] [Plugin] Searching: /usr/share/CCCorp/CloudCompare/plugins
# [18:59:48] [Plugin] Searching: /usr/share/runtime/share/CCCorp/CloudCompare/plugins
# [18:59:48] [Plugin] Searching: /run/host/user-share/CCCorp/CloudCompare/plugins
# [18:59:48] [Plugin] Searching: /run/host/share/CCCorp/CloudCompare/plugins
# [18:59:48] [Plugin][Additional I/O] New file extensions registered: ICM OUT PN POLY POV PV SOI SX
# [18:59:48] [Plugin][Core I/O] New file extensions registered:  GEOREF MA OBJ OFF PDMS PTX SBF STL VTK
# [18:59:48] [Plugin][CSV Matrix I/O] New file extensions registered: CSV
# [18:59:48] [Plugin][E57] New file extensions registered: E57
# [18:59:48] [Plugin][LAS (I/O Plugin)] New file extensions registered: LAS
# [18:59:48] [Plugin][PCD file I/O] New file extensions registered: PCD
# [18:59:48] [Plugin][Photoscan I/O] New file extensions registered: PSZ
# [18:59:48] [Global Shift] Max abs. coord = 1e+04 / max abs. diag = 1e+06
# [18:59:48] [LOAD]
# [18:59:48] Opening file: 'park_row.bin'
# [18:59:48] [BIN] Opening file 'park_row.bin'...
# [18:59:48] [BIN] Version 5.2 (coords: float / scalar: float)
# [18:59:48] [I/O] File 'park_row.bin' loaded successfully
# [18:59:48] Found one mesh with 17884 faces and 17532 vertices: '4_CEILING'
# [18:59:48] Found one mesh with 56543 faces and 60689 vertices: '7_COLUMN'
# [18:59:48] Found one mesh with 40681 faces and 62437 vertices: '8_DOOR'
# [18:59:48] Found one mesh with 15037 faces and 22667 vertices: '2_FLOOR'
# [18:59:48] Found one mesh with 402 faces and 756 vertices: '5_FOOTPATH'
# [18:59:48] Found one mesh with 143 faces and 142 vertices: '6_GRASS'
# [18:59:48] Found one mesh with 82512 faces and 82390 vertices: '13_OTHER'
# [18:59:48] Found one mesh with 580510 faces and 527064 vertices: '11_RAILING'
# [18:59:48] Found one mesh with 376 faces and 588 vertices: '3_ROOF'
# [18:59:48] Found one mesh with 12192 faces and 13396 vertices: '12_RWP'
# [18:59:48] Found one mesh with 27934 faces and 38444 vertices: '10_STAIR'
# [18:59:48] Found one mesh with 268200 faces and 242849 vertices: '1_WALL'
# [18:59:48] Found one mesh with 79072 faces and 123048 vertices: '9_WINDOW'
# [18:59:48] [LOAD] finished in 0.04 s.
# [18:59:48] [CHANGE MESH OUTPUT FORMAT]
# [18:59:48] Output export format (meshes) set to: PLY
# [18:59:48] [CHANGE MESH OUTPUT FORMAT] finished in 0.00 s.
# [18:59:48] [NO TIMESTAMP]
# [18:59:48] [NO TIMESTAMP] finished in 0.00 s.
# [18:59:48] [SAVE MESHES]
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_0.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_1.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_2.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_3.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_4.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_5.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_6.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_7.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_8.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_9.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_10.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_11.ply' saved successfully
# [18:59:48] [SAVING]
# [18:59:48] [I/O] File './park_row_12.ply' saved successfully
# [18:59:48] [SAVE MESHES] finished in 0.15 s.
# [18:59:48] Processed finished in 0.20 s.
#
# CloudCompare errors: QSocketNotifier: Can only be used with threads started with QThread
# libpng warning: iCCP: known incorrect sRGB profile
#
# park_row.bin
# park_row_0.ply
# park_row_1.ply
# park_row_2.ply
# park_row_3.ply
# park_row_4.ply
# park_row_5.ply
# park_row_6.ply
# park_row_7.ply
# park_row_8.ply
# park_row_9.ply
# park_row_10.ply
# park_row_11.ply
# park_row_12.ply

# %% [markdown]
# The issue with this method is that the meshes are saved in the order in which they are listed in the default mesh file.
# So the `4_CEILING` category which is listed first corresponds to `park_row_0.ply`.
#
# We could just map these in the processing script, but any new files being put in would need added to the lookup table. Not a great solution.
#
# ## Intermediate lookup table
#
# Instead, we can probably use the CloudCompare command line options to search for the appropriate mesh and if found, save it to a named file. Because the regex can match multiple entities in theory (though not in our examples), the only allowed file format is a .bin output from this stage.
#
# This means we'll need to do an intermediate saving step, then we can run a similar command on those outputs as above to convert them into appropriately named .ply files.

# %%
# We need to iterate over the categories, allowing for some of them not existing
categories = [
    "1_WALL",
    "2_FLOOR",
    "3_ROOF",
]


# Make a clean working dir for this test.
# Also copy the input file there
workdir = "./test_lookup"
if os.path.exists(workdir):
    shutil.rmtree(workdir)
os.makedirs(workdir)
new_path = Path(workdir) / input_stem
shutil.copy(input_path, str(new_path))

# First loop over the 
for category in categories:
    command_regex = [
        cloudcompare_path,
        "-SILENT",
        "-O", input_stem,
        "-SELECT_ENTITIES",
        "-REGEX", category,
        "-RENAME_ENTITIES", category.lower(),
        "-NO_TIMESTAMP", "-SAVE_MESHES"
    ]
    
    try:
        # Run the command as a subprocess
        result = subprocess.run(command_regex, cwd=workdir, check=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        # output is long so skip printing it
        print("CloudCompare errors:", result.stderr.decode())
    except subprocess.CalledProcessError as e:
        print(f"CloudCompare failed with error: {e.stderr.decode()}")

# Cloudcompare appends an index suffix to renamed files when multiple entities are loaded
# So we'll strip this suffix for deterministic file names going forward.
# Regular expression to match filenames ending with '_<integer>.bin'
import re
pattern = re.compile(r"^(.*?_\d+)\.(bin)$")

for file_path in Path(workdir).iterdir():
    if file_path.is_file() and pattern.match(file_path.name):
        new_file_stem = re.sub(r'_\d+$', '', file_path.stem)
        new_file_path = file_path.with_name(f"{new_file_stem}{file_path.suffix}")
        file_path.rename(new_file_path)
        print(f"Renamed '{file_path.name}' to '{new_file_path.name}'")

        # Now convert the file to a .ply file for use outside of CloudCompare.
        command_convert = [
            cloudcompare_path,
            "-SILENT",
            "-O", new_file_path.name,
            "-M_EXPORT_FMT", "PLY",
            "-NO_TIMESTAMP", "-SAVE_MESHES",
        ]
        try:
            # Run the command as a subprocess
            result = subprocess.run(command_convert, cwd=workdir, check=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
            # output is long so skip printing it
            print("CloudCompare errors:", result.stderr.decode())
        except subprocess.CalledProcessError as e:
            print(f"CloudCompare failed with error: {e.stderr.decode()}")

        # Finally unlink the intermediary .bin file
        new_file_path.unlink()

output_dir = Path(workdir)
for file in output_dir.iterdir():
    print(file.name)
# Out:
# CloudCompare errors: QSocketNotifier: Can only be used with threads started with QThread
# libpng warning: iCCP: known incorrect sRGB profile
#
# CloudCompare errors: QSocketNotifier: Can only be used with threads started with QThread
# libpng warning: iCCP: known incorrect sRGB profile
#
# CloudCompare errors: QSocketNotifier: Can only be used with threads started with QThread
# libpng warning: iCCP: known incorrect sRGB profile
#
# Renamed '1_wall_11.bin' to '1_wall.bin'
# CloudCompare errors: QSocketNotifier: Can only be used with threads started with QThread
# libpng warning: iCCP: known incorrect sRGB profile
#
# Renamed '2_floor_3.bin' to '2_floor.bin'
# CloudCompare errors: QSocketNotifier: Can only be used with threads started with QThread
# libpng warning: iCCP: known incorrect sRGB profile
#
# Renamed '3_roof_8.bin' to '3_roof.bin'
# CloudCompare errors: QSocketNotifier: Can only be used with threads started with QThread
# libpng warning: iCCP: known incorrect sRGB profile
#
# park_row.bin
# 1_wall.ply
# 2_floor.ply
# 3_roof.ply

# %% [markdown]
# Opening these up in Cloudcompare shows the meshes seem to be properly saved as .ply entities.
#
# This lets us now use a library like Open3D to process the meshes for our train/test/val splits without having to open the CloudCompare GUI a single time.
