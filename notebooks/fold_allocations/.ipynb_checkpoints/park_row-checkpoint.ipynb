# %%
import argparse
import logging
import numpy as np
import pyvista as pv

from pathlib import Path
from pointcept.supplemental.utils import disable_trame_logger
from pointcept.supplemental.mesh_processing import DataHandler, set_data_root, MeshAnalyser
from pointcept.supplemental.fold_allocation import (
    GridSplitter,
    process_folds,
    plot_mesh_folds,
    persist_best_iteration,
    load_best_iteration,
    crop_meshes_per_fold,
    save_splits
)

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', datefmt='%H:%M:%S')
logger = logging.getLogger(__name__)

set_data_root("../data")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
dh = DataHandler("brass_foundry")
dh.ensure_meshes()
# Out:
# 19:47:20 - INFO - Label brass_foundry already has extracted meshes.

# %%
analyser = MeshAnalyser(data_handler=dh)

# %%
to_exclude = []
pcds = analyser.generate_toy_pcds(resolution=0.15, excluded_categories=to_exclude)
# Out:
# 19:54:21 - INFO - Generating toy pointclouds for categories ['1_WALL', '2_FLOOR', '3_ROOF', '4_CEILING', '5_FOOTPATH', '6_GRASS', '7_COLUMN', '8_DOOR', '9_WINDOW', '10_STAIR', '11_RAILING', '12_RWP', '13_OTHER'].
# 19:54:21 - INFO - Sampling with resolution 0.15.
# 19:54:21 - INFO - Number of points after initial sampling: 1419913
# 19:54:22 - INFO - Number of points after Poisson Disk Sampling: 198406
# 19:54:22 - INFO - Number of points after initial sampling: 580373
# 19:54:22 - INFO - Number of points after Poisson Disk Sampling: 113364
# 19:54:22 - INFO - Number of points after initial sampling: 539115
# 19:54:22 - INFO - Number of points after Poisson Disk Sampling: 85507
# 19:54:22 - INFO - Number of points after initial sampling: 161107
# 19:54:22 - INFO - Number of points after Poisson Disk Sampling: 11796
# 19:54:22 - INFO - Number of points after initial sampling: 107781
# 19:54:22 - INFO - Number of points after Poisson Disk Sampling: 57169
# 19:54:22 - INFO - Number of points after initial sampling: 68692
# 19:54:22 - INFO - Number of points after Poisson Disk Sampling: 33163
# 19:54:22 - INFO - Number of points after initial sampling: 43142
# 19:54:22 - INFO - Number of points after Poisson Disk Sampling: 2860
# 19:54:22 - INFO - Number of points after initial sampling: 82772
# 19:54:23 - INFO - Number of points after Poisson Disk Sampling: 4814
# 19:54:23 - INFO - Number of points after initial sampling: 181122
# 19:54:23 - INFO - Number of points after Poisson Disk Sampling: 5024
# 19:54:23 - INFO - Number of points after initial sampling: 166342
# 19:54:23 - INFO - Number of points after Poisson Disk Sampling: 3684
# 19:54:23 - INFO - Number of points after initial sampling: 199392
# 19:54:23 - INFO - Number of points after Poisson Disk Sampling: 7194
# 19:54:23 - INFO - Number of points after initial sampling: 83569
# 19:54:23 - INFO - Number of points after Poisson Disk Sampling: 2030
# 19:54:24 - INFO - Number of points after initial sampling: 12774105
# 19:54:28 - INFO - Number of points after Poisson Disk Sampling: 181095
# 19:54:28 - INFO - Finished generating toy PCDs.

# %%
binning = analyser.evaluate_binning(pcds, x_cell_width=6.0, y_cell_width=6.0)
counts = binning['counts']
x_edges = binning['x_edges']
y_edges = binning['y_edges']
# Out:
# 19:54:30 - INFO - Binning is using 13 bins in X and 13 bins in Y based on cell widths of 6.0 and 6.0.

# %%
weights = [0.65, 0.2, 0.15]  # Intended area weights: training, evaluation, test
iterations = 1000  # Number of iterations to run
min_percentage_threshold = 8  # Minimum acceptable percentage per category per area
verbose = True  # Whether to print detailed statistics

# Create an instance of GridSplitter
grid_splitter = GridSplitter(
    counts=counts,
    x_edges=x_edges,
    y_edges=y_edges,
    weights=weights,
    iterations=iterations,
    min_percentage_threshold=min_percentage_threshold,
    verbose=verbose
)

# Run the algorithm
grid_splitter.run(random_seed=9897853)

# Plot the result
grid_splitter.plot()
# Out:
# 19:54:34 - INFO - New best equality score: 26137070.4895 at iteration 1
# 19:54:34 - INFO - New best equality score: 12064442.1597 at iteration 2
# 19:54:34 - INFO - New best equality score: 12055563.5586 at iteration 3
# 19:54:34 - INFO - New best equality score: 1030166.7136 at iteration 5
# 19:54:35 - INFO - New best equality score: 1023876.4342 at iteration 100
# 19:54:35 - INFO - New best equality score: 20565.5122 at iteration 142
# 19:54:35 - INFO - New best equality score: 17403.4855 at iteration 190
# 19:54:37 - INFO - New best equality score: 12178.3527 at iteration 997
# 19:54:37 - INFO -
# Best equality score after 1000 iterations: 12178.3527
# 19:54:37 - INFO - Best iteration: 997
# 19:54:37 - INFO -
# Final category counts and percentages per area:
#
# Area 1:
#   Area size: 108 cells (63.91% of total, intended 65.00%)
#   1_WALL: 99922 points (50.36% ± 0.11% of total 1_WALL)
#   2_FLOOR: 48049 points (42.38% ± 0.15% of total 2_FLOOR)
#   3_ROOF: 34273 points (40.08% ± 0.17% of total 3_ROOF)
#   4_CEILING: 4143 points (35.12% ± 0.44% of total 4_CEILING)
#   5_FOOTPATH: 42699 points (74.69% ± 0.18% of total 5_FOOTPATH)
#   6_GRASS: 17442 points (52.59% ± 0.27% of total 6_GRASS)
#   7_COLUMN: 1003 points (35.07% ± 0.89% of total 7_COLUMN)
#   8_DOOR: 1739 points (36.12% ± 0.69% of total 8_DOOR)
#   9_WINDOW: 1630 points (32.44% ± 0.66% of total 9_WINDOW)
#   10_STAIR: 704 points (19.11% ± 0.65% of total 10_STAIR)
#   11_RAILING: 2305 points (32.04% ± 0.55% of total 11_RAILING)
#   12_RWP: 747 points (36.80% ± 1.07% of total 12_RWP)
#   13_OTHER: 80659 points (44.54% ± 0.12% of total 13_OTHER)
#   Total points in area: 335315
#
# Area 2:
#   Area size: 26 cells (15.38% of total, intended 20.00%)
#   1_WALL: 33340 points (16.80% ± 0.08% of total 1_WALL)
#   2_FLOOR: 24471 points (21.59% ± 0.12% of total 2_FLOOR)
#   3_ROOF: 18316 points (21.42% ± 0.14% of total 3_ROOF)
#   4_CEILING: 246 points (2.09% ± 0.13% of total 4_CEILING)
#   5_FOOTPATH: 3679 points (6.44% ± 0.10% of total 5_FOOTPATH)
#   6_GRASS: 9037 points (27.25% ± 0.24% of total 6_GRASS)
#   7_COLUMN: 1020 points (35.66% ± 0.90% of total 7_COLUMN)
#   8_DOOR: 733 points (15.23% ± 0.52% of total 8_DOOR)
#   9_WINDOW: 981 points (19.53% ± 0.56% of total 9_WINDOW)
#   10_STAIR: 1183 points (32.11% ± 0.77% of total 10_STAIR)
#   11_RAILING: 2561 points (35.60% ± 0.56% of total 11_RAILING)
#   12_RWP: 458 points (22.56% ± 0.93% of total 12_RWP)
#   13_OTHER: 47538 points (26.25% ± 0.10% of total 13_OTHER)
#   Total points in area: 143563
#
# Area 3:
#   Area size: 35 cells (20.71% of total, intended 15.00%)
#   1_WALL: 65144 points (32.83% ± 0.11% of total 1_WALL)
#   2_FLOOR: 40844 points (36.03% ± 0.14% of total 2_FLOOR)
#   3_ROOF: 32918 points (38.50% ± 0.17% of total 3_ROOF)
#   4_CEILING: 7407 points (62.79% ± 0.45% of total 4_CEILING)
#   5_FOOTPATH: 10791 points (18.88% ± 0.16% of total 5_FOOTPATH)
#   6_GRASS: 6684 points (20.15% ± 0.22% of total 6_GRASS)
#   7_COLUMN: 837 points (29.27% ± 0.85% of total 7_COLUMN)
#   8_DOOR: 2342 points (48.65% ± 0.72% of total 8_DOOR)
#   9_WINDOW: 2413 points (48.03% ± 0.70% of total 9_WINDOW)
#   10_STAIR: 1797 points (48.78% ± 0.82% of total 10_STAIR)
#   11_RAILING: 2328 points (32.36% ± 0.55% of total 11_RAILING)
#   12_RWP: 825 points (40.64% ± 1.09% of total 12_RWP)
#   13_OTHER: 52898 points (29.21% ± 0.11% of total 13_OTHER)
#   Total points in area: 227228

# %%
# Process the folds and get the rectangles
fold_rectangles = process_folds(grid_splitter.best_grid)
# Out:
# Processing Fold 1
# Fold 1 has 9 rectangles with total perimeter 104.
# Processing Fold 2
# Fold 2 has 4 rectangles with total perimeter 36.
# Processing Fold 3
# Fold 3 has 7 rectangles with total perimeter 56.

# %%
persist_best_iteration(gridsplitter=grid_splitter, fold_rectangles=fold_rectangles, filename='brass_foundry_3fold.pkl')
# Out:
# Data from the best iteration has been saved to brass_foundry_3fold.pkl

# %%
loaded_data = load_best_iteration('brass_foundry_3fold.pkl')
# Out:
# 19:54:55 - INFO - Best Iteration: 997
# 19:54:55 - INFO - Best Equality Score: 12178.3527
# 19:54:55 - INFO -
# Final category counts per area:
#
# Area 1:
#   Area size: 108 cells (63.91% of total, intended 65.00%)
#   1_WALL: 99922 points (50.36% of total 1_WALL)
#   2_FLOOR: 48049 points (42.38% of total 2_FLOOR)
#   3_ROOF: 34273 points (40.08% of total 3_ROOF)
#   4_CEILING: 4143 points (35.12% of total 4_CEILING)
#   5_FOOTPATH: 42699 points (74.69% of total 5_FOOTPATH)
#   6_GRASS: 17442 points (52.59% of total 6_GRASS)
#   7_COLUMN: 1003 points (35.07% of total 7_COLUMN)
#   8_DOOR: 1739 points (36.12% of total 8_DOOR)
#   9_WINDOW: 1630 points (32.44% of total 9_WINDOW)
#   10_STAIR: 704 points (19.11% of total 10_STAIR)
#   11_RAILING: 2305 points (32.04% of total 11_RAILING)
#   12_RWP: 747 points (36.80% of total 12_RWP)
#   13_OTHER: 80659 points (44.54% of total 13_OTHER)
#   Total points in area: 335315
#
# Area 2:
#   Area size: 26 cells (15.38% of total, intended 20.00%)
#   1_WALL: 33340 points (16.80% of total 1_WALL)
#   2_FLOOR: 24471 points (21.59% of total 2_FLOOR)
#   3_ROOF: 18316 points (21.42% of total 3_ROOF)
#   4_CEILING: 246 points (2.09% of total 4_CEILING)
#   5_FOOTPATH: 3679 points (6.44% of total 5_FOOTPATH)
#   6_GRASS: 9037 points (27.25% of total 6_GRASS)
#   7_COLUMN: 1020 points (35.66% of total 7_COLUMN)
#   8_DOOR: 733 points (15.23% of total 8_DOOR)
#   9_WINDOW: 981 points (19.53% of total 9_WINDOW)
#   10_STAIR: 1183 points (32.11% of total 10_STAIR)
#   11_RAILING: 2561 points (35.60% of total 11_RAILING)
#   12_RWP: 458 points (22.56% of total 12_RWP)
#   13_OTHER: 47538 points (26.25% of total 13_OTHER)
#   Total points in area: 143563
#
# Area 3:
#   Area size: 35 cells (20.71% of total, intended 15.00%)
#   1_WALL: 65144 points (32.83% of total 1_WALL)
#   2_FLOOR: 40844 points (36.03% of total 2_FLOOR)
#   3_ROOF: 32918 points (38.50% of total 3_ROOF)
#   4_CEILING: 7407 points (62.79% of total 4_CEILING)
#   5_FOOTPATH: 10791 points (18.88% of total 5_FOOTPATH)
#   6_GRASS: 6684 points (20.15% of total 6_GRASS)
#   7_COLUMN: 837 points (29.27% of total 7_COLUMN)
#   8_DOOR: 2342 points (48.65% of total 8_DOOR)
#   9_WINDOW: 2413 points (48.03% of total 9_WINDOW)
#   10_STAIR: 1797 points (48.78% of total 10_STAIR)
#   11_RAILING: 2328 points (32.36% of total 11_RAILING)
#   12_RWP: 825 points (40.64% of total 12_RWP)
#   13_OTHER: 52898 points (29.21% of total 13_OTHER)
#   Total points in area: 227228
# Data from brass_foundry_3fold.pkl has been loaded successfully.

# %%
# fold_meshes = crop_meshes_per_fold(
#     dh.extracted_meshes,
#     loaded_data['fold_rectangles'],
#     loaded_data['x_edges'],
#     loaded_data['y_edges']
# )
# Out:
# 19:54:57 - INFO - Processing Fold 1
# 19:55:45 - INFO - Processing Fold 2
# 19:56:07 - INFO - Processing Fold 3

# %%
plot_mesh_folds(fold_meshes)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800>

# %%
fold_meshes[1]['1_WALL']
# Out:
# UnstructuredGrid (0x7fb906a413c0)
#   N Cells:    38769
#   N Points:   31465
#   X Bounds:   -3.284e+01, 1.349e+01
#   Y Bounds:   -3.530e+01, 1.166e+01
#   Z Bounds:   -1.760e+01, -1.263e+00
#   N Arrays:   2

# %%
fold_name_map = {
    1: 'train',
    2: 'test',
    3: 'eval',
}

fold_meshes_2 = {fold_name_map[k]: v for k, v in fold_meshes.items()}
fold_meshes_2
# Out:
# {'train': {'1_WALL': UnstructuredGrid (0x7fb906a413c0)
#     N Cells:    38769
#     N Points:   31465
#     X Bounds:   -3.284e+01, 1.349e+01
#     Y Bounds:   -3.530e+01, 1.166e+01
#     Z Bounds:   -1.760e+01, -1.263e+00
#     N Arrays:   2,
#   '2_FLOOR': UnstructuredGrid (0x7fb906a42440)
#     N Cells:    1320
#     N Points:   1036
#     X Bounds:   -1.129e+01, 1.875e+01
#     Y Bounds:   -3.440e+01, 1.055e+01
#     Z Bounds:   -1.801e+01, -4.250e+00
#     N Arrays:   2,
#   '3_ROOF': UnstructuredGrid (0x7fb906a42f20)
#     N Cells:    2393
#     N Points:   1845
#     X Bounds:   -1.218e+01, 1.137e+01
#     Y Bounds:   -3.472e+01, 1.121e+01
#     Z Bounds:   -1.436e+01, 3.895e-01
#     N Arrays:   2,
#   '4_CEILING': UnstructuredGrid (0x7fb904116080)
#     N Cells:    893
#     N Points:   346
#     X Bounds:   -1.129e+01, 7.959e+00
#     Y Bounds:   1.295e+00, 1.030e+01
#     Z Bounds:   -1.384e+01, -7.897e+00
#     N Arrays:   2,
#   '5_FOOTPATH': UnstructuredGrid (0x7fb906a41360)
#     N Cells:    328
#     N Points:   272
#     X Bounds:   -3.893e+01, 1.864e+01
#     Y Bounds:   -3.819e+01, 3.819e+01
#     Z Bounds:   -1.851e+01, -1.546e+01
#     N Arrays:   2,
#   '6_GRASS': UnstructuredGrid (0x7fb904116e60)
#     N Cells:    401
#     N Points:   340
#     X Bounds:   -3.688e+01, 1.783e+01
#     Y Bounds:   -3.819e+01, 1.944e+01
#     Z Bounds:   -1.793e+01, -1.579e+01
#     N Arrays:   2,
#   '7_COLUMN': UnstructuredGrid (0x7fb906a43ca0)
#     N Cells:    1200
#     N Points:   800
#     X Bounds:   -1.099e+01, 8.978e+00
#     Y Bounds:   -3.281e+01, -1.166e+01
#     Z Bounds:   -1.708e+01, -1.287e+01
#     N Arrays:   2,
#   '8_DOOR': UnstructuredGrid (0x7fb906a3a980)
#     N Cells:    1966
#     N Points:   1274
#     X Bounds:   -1.184e+01, 4.637e+00
#     Y Bounds:   -2.780e+01, 1.067e+01
#     Z Bounds:   -1.708e+01, -1.356e+01
#     N Arrays:   2,
#   '9_WINDOW': UnstructuredGrid (0x7fb906a42d40)
#     N Cells:    6973
#     N Points:   4199
#     X Bounds:   -1.183e+01, 7.397e+00
#     Y Bounds:   -3.492e+01, 1.078e+01
#     Z Bounds:   -1.658e+01, -2.090e+00
#     N Arrays:   2,
#   '10_STAIR': UnstructuredGrid (0x7fb906a42bc0)
#     N Cells:    6228
#     N Points:   2463
#     X Bounds:   -9.000e+00, 7.375e+00
#     Y Bounds:   -2.528e+01, 1.018e+01
#     Z Bounds:   -1.705e+01, -4.250e+00
#     N Arrays:   2,
#   '11_RAILING': UnstructuredGrid (0x7fb906a42260)
#     N Cells:    18976
#     N Points:   12751
#     X Bounds:   -1.634e+01, 9.366e+00
#     Y Bounds:   -3.372e+01, 1.015e+01
#     Z Bounds:   -1.717e+01, -7.361e+00
#     N Arrays:   2,
#   '12_RWP': UnstructuredGrid (0x7fb906a43c40)
#     N Cells:    2584
#     N Points:   2229
#     X Bounds:   -1.233e+01, 8.831e+00
#     Y Bounds:   -2.750e+01, 1.134e+01
#     Z Bounds:   -1.679e+01, -8.413e+00
#     N Arrays:   2,
#   '13_OTHER': UnstructuredGrid (0x7fb906a41fc0)
#     N Cells:    2078825
#     N Points:   1962542
#     X Bounds:   -1.182e+01, 1.340e+01
#     Y Bounds:   -3.452e+01, 1.007e+01
#     Z Bounds:   -1.683e+01, -4.542e+00
#     N Arrays:   2},
#  'test': {'1_WALL': UnstructuredGrid (0x7fb906a42020)
#     N Cells:    18535
#     N Points:   14917
#     X Bounds:   -6.715e+00, 1.433e+01
#     Y Bounds:   -3.530e+01, 1.402e+00
#     Z Bounds:   -1.744e+01, -9.369e+00
#     N Arrays:   2,
#   '2_FLOOR': UnstructuredGrid (0x7fb9041371c0)
#     N Cells:    825
#     N Points:   713
#     X Bounds:   -1.129e+01, 1.349e+01
#     Y Bounds:   -3.440e+01, 6.865e+00
#     Z Bounds:   -1.733e+01, -8.278e+00
#     N Arrays:   2,
#   '3_ROOF': UnstructuredGrid (0x7fb906a42e00)
#     N Cells:    1715
#     N Points:   1304
#     X Bounds:   -7.305e+00, 1.451e+01
#     Y Bounds:   -3.472e+01, 4.444e+00
#     Z Bounds:   -1.395e+01, -4.825e+00
#     N Arrays:   2,
#   '4_CEILING': UnstructuredGrid (0x7fb9041366e0)
#     N Cells:    32
#     N Points:   20
#     X Bounds:   1.167e+01, 1.349e+01
#     Y Bounds:   -1.139e+01, -5.584e+00
#     Z Bounds:   -1.387e+01, -1.385e+01
#     N Arrays:   2,
#   '5_FOOTPATH': UnstructuredGrid (0x7fb906a43fa0)
#     N Cells:    113
#     N Points:   101
#     X Bounds:   8.498e+00, 3.893e+01
#     Y Bounds:   -3.819e+01, -1.047e+01
#     Z Bounds:   -1.818e+01, -1.726e+01
#     N Arrays:   2,
#   '6_GRASS': UnstructuredGrid (0x7fb904135c00)
#     N Cells:    58
#     N Points:   66
#     X Bounds:   1.378e+01, 3.438e+01
#     Y Bounds:   -3.221e+01, -6.608e+00
#     Z Bounds:   -1.811e+01, -1.736e+01
#     N Arrays:   2,
#   '7_COLUMN': UnstructuredGrid (0x7fb906a42380)
#     N Cells:    1212
#     N Points:   808
#     X Bounds:   -2.715e+00, 1.342e+01
#     Y Bounds:   -3.286e+01, -1.434e+01
#     Z Bounds:   -1.708e+01, -1.286e+01
#     N Arrays:   2,
#   '8_DOOR': UnstructuredGrid (0x7fb8fd4fea40)
#     N Cells:    1202
#     N Points:   768
#     X Bounds:   -1.588e+00, 1.397e+01
#     Y Bounds:   -2.095e+01, -8.730e+00
#     Z Bounds:   -1.708e+01, -1.419e+01
#     N Arrays:   2,
#   '9_WINDOW': UnstructuredGrid (0x7fb8fd4fe5c0)
#     N Cells:    3320
#     N Points:   2023
#     X Bounds:   8.167e+00, 1.390e+01
#     Y Bounds:   -3.058e+01, -8.844e+00
#     Z Bounds:   -1.657e+01, -1.120e+01
#     N Arrays:   2,
#   '10_STAIR': UnstructuredGrid (0x7fb8fd4fd540)
#     N Cells:    8898
#     N Points:   2516
#     X Bounds:   -2.499e+00, 1.329e+01
#     Y Bounds:   -2.463e+01, -1.674e+01
#     Z Bounds:   -1.708e+01, -1.258e+01
#     N Arrays:   2,
#   '11_RAILING': UnstructuredGrid (0x7fb906a27760)
#     N Cells:    19369
#     N Points:   12491
#     X Bounds:   -3.211e+00, 1.332e+01
#     Y Bounds:   -2.801e+01, -1.399e+01
#     Z Bounds:   -1.692e+01, -7.361e+00
#     N Arrays:   2,
#   '12_RWP': UnstructuredGrid (0x7fb906a26020)
#     N Cells:    653
#     N Points:   440
#     X Bounds:   -1.719e+00, 1.451e+01
#     Y Bounds:   -3.424e+01, 1.088e+00
#     Z Bounds:   -1.742e+01, -1.097e+01
#     N Arrays:   2,
#   '13_OTHER': UnstructuredGrid (0x7fb8fd4fd420)
#     N Cells:    1308784
#     N Points:   1253408
#     X Bounds:   -1.130e+01, 1.434e+01
#     Y Bounds:   -3.432e+01, -5.245e+00
#     Z Bounds:   -1.683e+01, -5.604e+00
#     N Arrays:   2},
#  'eval': {'1_WALL': UnstructuredGrid (0x7fb906a27700)
#     N Cells:    10177
#     N Points:   6721
#     X Bounds:   -1.129e+01, 1.887e+01
#     Y Bounds:   -1.571e+01, 1.096e+01
#     Z Bounds:   -1.744e+01, -1.263e+00
#     N Arrays:   2,
#   '2_FLOOR': UnstructuredGrid (0x7fb906a269e0)
#     N Cells:    917
#     N Points:   778
#     X Bounds:   -1.129e+01, 2.000e+01
#     Y Bounds:   -2.722e+01, 1.055e+01
#     Z Bounds:   -1.801e+01, -4.250e+00
#     N Arrays:   2,
#   '3_ROOF': UnstructuredGrid (0x7fb906a25e40)
#     N Cells:    3399
#     N Points:   2866
#     X Bounds:   -1.183e+01, 1.895e+01
#     Y Bounds:   -1.799e+01, 1.121e+01
#     Z Bounds:   -1.395e+01, 3.895e-01
#     N Arrays:   2,
#   '4_CEILING': UnstructuredGrid (0x7fb8fd4fd300)
#     N Cells:    1243
#     N Points:   453
#     X Bounds:   -1.129e+01, 1.804e+01
#     Y Bounds:   -1.139e+01, 1.030e+01
#     Z Bounds:   -1.500e+01, -7.897e+00
#     N Arrays:   2,
#   '5_FOOTPATH': UnstructuredGrid (0x7fb906a24280)
#     N Cells:    115
#     N Points:   123
#     X Bounds:   1.049e+01, 3.893e+01
#     Y Bounds:   -1.522e+01, 2.953e+01
#     Z Bounds:   -1.836e+01, -1.746e+01
#     N Arrays:   2,
#   '6_GRASS': UnstructuredGrid (0x7fb906a27940)
#     N Cells:    70
#     N Points:   79
#     X Bounds:   1.181e+01, 3.203e+01
#     Y Bounds:   -1.277e+01, 1.567e+01
#     Z Bounds:   -1.812e+01, -1.736e+01
#     N Arrays:   2,
#   '7_COLUMN': UnstructuredGrid (0x7fb906a250c0)
#     N Cells:    1040
#     N Points:   679
#     X Bounds:   -1.763e+00, 7.362e+00
#     Y Bounds:   -1.214e+01, 5.625e-01
#     Z Bounds:   -1.708e+01, -1.287e+01
#     N Arrays:   2,
#   '8_DOOR': UnstructuredGrid (0x7fb906a26920)
#     N Cells:    3080
#     N Points:   1884
#     X Bounds:   -1.318e+00, 1.348e+01
#     Y Bounds:   -1.448e+01, 8.808e+00
#     Z Bounds:   -1.708e+01, -6.070e+00
#     N Arrays:   2,
#   '9_WINDOW': UnstructuredGrid (0x7fb906a26680)
#     N Cells:    11788
#     N Points:   6554
#     X Bounds:   -1.758e+00, 1.844e+01
#     Y Bounds:   -1.499e+01, 9.593e+00
#     Z Bounds:   -1.655e+01, -2.090e+00
#     N Arrays:   2,
#   '10_STAIR': UnstructuredGrid (0x7fb906a279a0)
#     N Cells:    14032
#     N Points:   4829
#     X Bounds:   3.042e+00, 7.899e+00
#     Y Bounds:   -1.198e+01, 1.018e+01
#     Z Bounds:   -1.708e+01, -4.249e+00
#     N Arrays:   2,
#   '11_RAILING': UnstructuredGrid (0x7fb906a27a00)
#     N Cells:    27923
#     N Points:   17306
#     X Bounds:   -5.835e-01, 7.924e+00
#     Y Bounds:   -1.446e+01, 1.014e+01
#     Z Bounds:   -1.691e+01, -6.597e+00
#     N Arrays:   2,
#   '12_RWP': UnstructuredGrid (0x7fb906a277c0)
#     N Cells:    5858
#     N Points:   5255
#     X Bounds:   -2.115e+00, 1.895e+01
#     Y Bounds:   -1.593e+01, 1.134e+01
#     Z Bounds:   -1.695e+01, -8.413e+00
#     N Arrays:   2,
#   '13_OTHER': UnstructuredGrid (0x7fb906a27880)
#     N Cells:    1065383
#     N Points:   1005955
#     X Bounds:   -1.130e+01, 1.970e+01
#     Y Bounds:   -2.795e+01, 1.007e+01
#     Z Bounds:   -1.683e+01, -4.302e+00
#     N Arrays:   2}}

# %%
# import vtk
# def save_splits(dh, splits):
#     """
#     Merge cells for each fold-category permutation and save them to disk.

#     Args:
#         dh (DataHandler): An object with a split_dirs attribute, containing directories for 'train', 'test', 'eval'.
#         splits (dict): A dictionary containing fold-category mappings of cells. 
#                        Example: {'train': {'category1': [cell1, cell2, ...], 'category2': [...]}}

#     Returns:
#         None: The function saves the merged meshes directly to disk.
#     """
#     dh._ensure_split_dirs()
#     # Iterate over the splits dictionary (e.g., 'train', 'test', 'eval')
#     for fold, categories in splits.items():
#         # Get the appropriate directory for the fold from DataHandler
#         fold_dir = dh.split_dirs.get(fold)
#         cell_counter = 0
#         # Iterate over each category in the fold
#         for category, mesh in categories.items():
#             if mesh.n_points == 0 and combined_mesh.n_cells == 0:
#                 logger.warn(f"Fold: {fold}, Category: {category} has an empty mesh!")
#             mesh.GetPointData().SetActiveNormals('Normals')

#             output_file = fold_dir / f"{category.lower()}.ply"           
#             # Save the merged mesh to disk using vtk for control over color storage
#             writer = vtk.vtkPLYWriter()
#             writer.SetFileName(output_file.as_posix())
#             writer.SetInputData(mesh)
#             writer.SetColorModeToDefault()  # Ensure colors are written from the Scalars
#             writer.SetArrayName('RGB')
#             writer.Write()
#             logger.info(f"Fold {fold}, category {category} saved.")

save_splits(dh, fold_meshes_2)
# Out:
# 20:26:16 - INFO - Fold train, category 1_WALL saved.
# 20:26:16 - INFO - Fold train, category 2_FLOOR saved.
# 20:26:16 - INFO - Fold train, category 3_ROOF saved.
# 20:26:16 - INFO - Fold train, category 4_CEILING saved.
# 20:26:16 - INFO - Fold train, category 5_FOOTPATH saved.
# 20:26:16 - INFO - Fold train, category 6_GRASS saved.
# 20:26:16 - INFO - Fold train, category 7_COLUMN saved.
# 20:26:16 - INFO - Fold train, category 8_DOOR saved.
# 20:26:17 - INFO - Fold train, category 9_WINDOW saved.
# 20:26:17 - INFO - Fold train, category 10_STAIR saved.
# 20:26:17 - INFO - Fold train, category 11_RAILING saved.
# 20:26:17 - INFO - Fold train, category 12_RWP saved.
# 20:26:17 - INFO - Fold train, category 13_OTHER saved.
# 20:26:17 - INFO - Fold test, category 1_WALL saved.
# 20:26:17 - INFO - Fold test, category 2_FLOOR saved.
# 20:26:17 - INFO - Fold test, category 3_ROOF saved.
# 20:26:17 - INFO - Fold test, category 4_CEILING saved.
# 20:26:17 - INFO - Fold test, category 5_FOOTPATH saved.
# 20:26:17 - INFO - Fold test, category 6_GRASS saved.
# 20:26:17 - INFO - Fold test, category 7_COLUMN saved.
# 20:26:17 - INFO - Fold test, category 8_DOOR saved.
# 20:26:17 - INFO - Fold test, category 9_WINDOW saved.
# 20:26:17 - INFO - Fold test, category 10_STAIR saved.
# 20:26:17 - INFO - Fold test, category 11_RAILING saved.
# 20:26:17 - INFO - Fold test, category 12_RWP saved.
# 20:26:17 - INFO - Fold test, category 13_OTHER saved.
# 20:26:17 - INFO - Fold eval, category 1_WALL saved.
# 20:26:17 - INFO - Fold eval, category 2_FLOOR saved.
# 20:26:17 - INFO - Fold eval, category 3_ROOF saved.
# 20:26:17 - INFO - Fold eval, category 4_CEILING saved.
# 20:26:17 - INFO - Fold eval, category 5_FOOTPATH saved.
# 20:26:17 - INFO - Fold eval, category 6_GRASS saved.
# 20:26:17 - INFO - Fold eval, category 7_COLUMN saved.
# 20:26:17 - INFO - Fold eval, category 8_DOOR saved.
# 20:26:17 - INFO - Fold eval, category 9_WINDOW saved.
# 20:26:17 - INFO - Fold eval, category 10_STAIR saved.
# 20:26:17 - INFO - Fold eval, category 11_RAILING saved.
# 20:26:17 - INFO - Fold eval, category 12_RWP saved.
# 20:26:17 - INFO - Fold eval, category 13_OTHER saved.

# %%
# import vtk

# def map_grid_to_spatial(min_col, max_col, min_row, max_row, x_edges, y_edges):
#     """
#     Map grid indices to spatial coordinates using x_edges and y_edges.
    
#     Parameters:
#         min_col, max_col, min_row, max_row (int): Grid indices.
#         x_edges, y_edges (array-like): Bin edges for x and y axes.
    
#     Returns:
#         tuple: xmin, xmax, ymin, ymax mapped to spatial coordinates.
#     """
#     xmin = x_edges[min_col]
#     xmax = x_edges[max_col + 1]  # +1 because x_edges has length grid_size_x + 1
#     ymin = y_edges[min_row]
#     ymax = y_edges[max_row + 1]  # +1 because y_edges has length grid_size_y + 1
#     return xmin, xmax, ymin, ymax
    
# def crop_meshes_per_fold(category_meshes, fold_rectangles, x_edges, y_edges):
#     """
#     Crop meshes for each fold based on rectangular bounding boxes using sequential plane clipping.

#     Parameters:
#         category_meshes (dict): Dictionary of category names and corresponding PyVista meshes.
#         fold_rectangles (dict): Dictionary of fold IDs and bounding boxes.
#         x_edges (array-like): Bin edges for x-axis.
#         y_edges (array-like): Bin edges for y-axis.

#     Returns:
#         dict: A dictionary containing cropped meshes for each fold and category.
#     """
#     fold_meshes = {}
#     for fold_id, rectangles in fold_rectangles.items():
#         logging.info(f"Processing Fold {fold_id}")
        
#         # For each category, we'll create a list to store cropped meshes
#         fold_category_meshes = {}
        
#         for category, mesh in category_meshes.items():
#             mesh = pv.wrap(mesh)  # Ensure the mesh is a PyVista object
            
#             # Initialize an empty list to collect cropped meshes for this category and fold
#             cropped_meshes = []
            
#             for rect in rectangles:
#                 # Map grid indices to spatial coordinates
#                 xmin, xmax, ymin, ymax = map_grid_to_spatial(
#                     rect['min_col'], rect['max_col'], rect['min_row'], rect['max_row'], x_edges, y_edges)
                
#                 # Create planes for clipping
#                 planes = [
#                     ('x', xmin, False),  # Left plane
#                     ('x', xmax, True),   # Right plane
#                     ('y', ymin, False),  # Bottom plane
#                     ('y', ymax, True),   # Top plane
#                 ]
                
#                 # Start with the original mesh and sequentially clip with each plane
#                 clipped_mesh = mesh
#                 for axis, origin, invert in planes:
#                     normal = {'x': (1, 0, 0), 'y': (0, 1, 0)}[axis]
#                     point = [origin, 0, 0] if axis == 'x' else [0, origin, 0]
#                     clipped_mesh = clipped_mesh.clip(normal=normal, origin=point, invert=invert)
#                     if clipped_mesh.n_points == 0:
#                         break  # No points left, exit early
#                 if clipped_mesh.n_points > 0:
#                     cropped_meshes.append(clipped_mesh)
#                 else:
#                     logging.debug(f"Cropping resulted in empty mesh for rectangle {rect} in category {category}")
                
#             # Merge the cropped meshes for this category and fold
#             if cropped_meshes:
#                 combined_mesh = cropped_meshes[0]
#                 for cm in cropped_meshes[1:]:
#                     combined_mesh = combined_mesh.merge(cm, merge_points=True, main_has_priority=False)
#                 fold_category_meshes[category] = combined_mesh
#             else:
#                 logging.warning(f"No mesh data in Fold {fold_id} for category {category}")
        
#         # Store the combined meshes per fold
#         fold_meshes[fold_id] = fold_category_meshes

#     return fold_meshes

    
# fold_meshes = crop_meshes_per_fold(
#     dh.extracted_meshes,
#     loaded_data['fold_rectangles'],
#     loaded_data['x_edges'],
#     loaded_data['y_edges']
# )
# Out:
# 20:24:50 - INFO - Processing Fold 1
# 20:24:57 - INFO - Processing Fold 2
# 20:25:12 - INFO - Processing Fold 3

# %%
dh.generate_and_save_fold_clouds(resolution=0.05, poisson_radius=0.049, save_all_formats=True)
# Out:
# 20:28:16 - INFO - Number of points after initial sampling: 35689315
# 20:28:35 - INFO - Number of points after Poisson Disk Sampling: 2675486
# 20:28:36 - INFO - Saving cloud as .las format...
# 20:28:39 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/1_wall.las
# 20:28:40 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/1_wall.pth in .pth format.
# 20:28:40 - INFO - Number of points after initial sampling: 4100358
# 20:28:43 - INFO - Number of points after Poisson Disk Sampling: 1016903
# 20:28:43 - INFO - Saving cloud as .las format...
# 20:28:45 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/2_floor.las
# 20:28:45 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/2_floor.pth in .pth format.
# 20:28:45 - INFO - Number of points after initial sampling: 3631659
# 20:28:47 - INFO - Number of points after Poisson Disk Sampling: 554406
# 20:28:47 - INFO - Saving cloud as .las format...
# 20:28:48 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/3_roof.las
# 20:28:48 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/3_roof.pth in .pth format.
# 20:28:48 - INFO - Number of points after initial sampling: 9294936
# 20:28:53 - INFO - Number of points after Poisson Disk Sampling: 862783
# 20:28:56 - INFO - Saving cloud as .las format...
# 20:28:57 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/4_ceiling.las
# 20:28:57 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/4_ceiling.pth in .pth format.
# 20:28:57 - INFO - Number of points after initial sampling: 2821962
# 20:28:59 - INFO - Number of points after Poisson Disk Sampling: 499001
# 20:28:59 - INFO - Saving cloud as .las format...
# 20:29:00 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/5_footpath.las
# 20:29:00 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/5_footpath.pth in .pth format.
# 20:29:00 - INFO - Number of points after initial sampling: 528116
# 20:29:00 - INFO - Number of points after Poisson Disk Sampling: 137340
# 20:29:00 - INFO - Saving cloud as .las format...
# 20:29:00 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/6_grass.las
# 20:29:00 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/6_grass.pth in .pth format.
# 20:29:00 - INFO - Number of points after initial sampling: 1590849
# 20:29:01 - INFO - Number of points after Poisson Disk Sampling: 179276
# 20:29:02 - INFO - Saving cloud as .las format...
# 20:29:02 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/7_column.las
# 20:29:02 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/7_column.pth in .pth format.
# 20:29:02 - INFO - Number of points after initial sampling: 2302198
# 20:29:03 - INFO - Number of points after Poisson Disk Sampling: 110389
# 20:29:03 - INFO - Saving cloud as .las format...
# 20:29:03 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/8_door.las
# 20:29:03 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/8_door.pth in .pth format.
# 20:29:03 - INFO - Number of points after initial sampling: 2554073
# 20:29:04 - INFO - Number of points after Poisson Disk Sampling: 104571
# 20:29:04 - INFO - Saving cloud as .las format...
# 20:29:04 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/9_window.las
# 20:29:04 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/9_window.pth in .pth format.
# 20:29:05 - INFO - Number of points after initial sampling: 2678024
# 20:29:05 - INFO - Number of points after Poisson Disk Sampling: 52783
# 20:29:05 - INFO - Saving cloud as .las format...
# 20:29:06 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/10_stair.las
# 20:29:06 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/10_stair.pth in .pth format.
# 20:29:06 - INFO - Number of points after initial sampling: 650669
# 20:29:06 - INFO - Number of points after Poisson Disk Sampling: 19154
# 20:29:06 - INFO - Saving cloud as .las format...
# 20:29:06 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/11_railing.las
# 20:29:06 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/11_railing.pth in .pth format.
# 20:29:06 - INFO - Number of points after initial sampling: 117478
# 20:29:06 - INFO - Number of points after Poisson Disk Sampling: 3733
# 20:29:06 - INFO - Saving cloud as .las format...
# 20:29:06 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/12_rwp.las
# 20:29:06 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/12_rwp.pth in .pth format.
# 20:29:06 - INFO - Number of points after initial sampling: 483135
# 20:29:07 - INFO - Number of points after Poisson Disk Sampling: 31144
# 20:29:07 - INFO - Saving cloud as .las format...
# 20:29:07 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/train/13_other.las
# 20:29:07 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/train/13_other.pth in .pth format.
# 20:29:08 - INFO - Combined LAS file saved to ../data/clouds/res0.05_pr0.049/park_row/train/combined.las with 6246969 points.
# 20:29:09 - INFO - Combined data saved to ../data/clouds/res0.05_pr0.049/park_row/train/combined.pth
# 20:29:10 - INFO - Number of points after initial sampling: 30341318
# 20:29:22 - INFO - Number of points after Poisson Disk Sampling: 721856
# 20:29:22 - INFO - Saving cloud as .las format...
# 20:29:23 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/1_wall.las
# 20:29:23 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/1_wall.pth in .pth format.
# 20:29:23 - INFO - Number of points after initial sampling: 4701853
# 20:29:26 - INFO - Number of points after Poisson Disk Sampling: 389973
# 20:29:26 - INFO - Saving cloud as .las format...
# 20:29:27 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/2_floor.las
# 20:29:27 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/2_floor.pth in .pth format.
# 20:29:27 - INFO - Number of points after initial sampling: 1930661
# 20:29:27 - INFO - Number of points after Poisson Disk Sampling: 169478
# 20:29:27 - INFO - Saving cloud as .las format...
# 20:29:28 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/3_roof.las
# 20:29:28 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/3_roof.pth in .pth format.
# 20:29:28 - INFO - Number of points after initial sampling: 30186651
# 20:29:38 - INFO - Number of points after Poisson Disk Sampling: 451979
# 20:29:38 - INFO - Saving cloud as .las format...
# 20:29:38 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/4_ceiling.las
# 20:29:39 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/4_ceiling.pth in .pth format.
# 20:29:39 - INFO - Number of points after initial sampling: 2159356
# 20:29:39 - INFO - Number of points after Poisson Disk Sampling: 237187
# 20:29:40 - INFO - Saving cloud as .las format...
# 20:29:40 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/5_footpath.las
# 20:29:40 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/5_footpath.pth in .pth format.
# 20:29:40 - INFO - Number of points after initial sampling: 267049
# 20:29:40 - INFO - Number of points after Poisson Disk Sampling: 63788
# 20:29:40 - INFO - Saving cloud as .las format...
# 20:29:40 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/6_grass.las
# 20:29:40 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/6_grass.pth in .pth format.
# 20:29:40 - INFO - Number of points after initial sampling: 192013
# 20:29:40 - INFO - Number of points after Poisson Disk Sampling: 23998
# 20:29:40 - INFO - Saving cloud as .las format...
# 20:29:40 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/7_column.las
# 20:29:40 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/7_column.pth in .pth format.
# 20:29:40 - INFO - Number of points after initial sampling: 236056
# 20:29:41 - INFO - Number of points after Poisson Disk Sampling: 17883
# 20:29:41 - INFO - Saving cloud as .las format...
# 20:29:41 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/8_door.las
# 20:29:41 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/8_door.pth in .pth format.
# 20:29:41 - INFO - Number of points after initial sampling: 1190295
# 20:29:41 - INFO - Number of points after Poisson Disk Sampling: 46493
# 20:29:41 - INFO - Saving cloud as .las format...
# 20:29:41 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/9_window.las
# 20:29:41 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/9_window.pth in .pth format.
# 20:29:41 - INFO - Number of points after initial sampling: 554307
# 20:29:42 - INFO - Number of points after Poisson Disk Sampling: 12794
# 20:29:42 - INFO - Saving cloud as .las format...
# 20:29:42 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/10_stair.las
# 20:29:42 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/10_stair.pth in .pth format.
# 20:29:42 - INFO - Number of points after initial sampling: 350849
# 20:29:42 - INFO - Number of points after Poisson Disk Sampling: 9460
# 20:29:42 - INFO - Saving cloud as .las format...
# 20:29:42 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/11_railing.las
# 20:29:42 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/11_railing.pth in .pth format.
# 20:29:42 - INFO - Number of points after initial sampling: 32629
# 20:29:42 - INFO - Number of points after Poisson Disk Sampling: 1023
# 20:29:42 - INFO - Saving cloud as .las format...
# 20:29:42 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/12_rwp.las
# 20:29:42 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/12_rwp.pth in .pth format.
# 20:29:42 - INFO - Number of points after initial sampling: 301401
# 20:29:42 - INFO - Number of points after Poisson Disk Sampling: 17888
# 20:29:42 - INFO - Saving cloud as .las format...
# 20:29:42 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/test/13_other.las
# 20:29:42 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/test/13_other.pth in .pth format.
# 20:29:42 - INFO - Combined LAS file saved to ../data/clouds/res0.05_pr0.049/park_row/test/combined.las with 2163800 points.
# 20:29:43 - INFO - Combined data saved to ../data/clouds/res0.05_pr0.049/park_row/test/combined.pth
# 20:29:43 - INFO - Number of points after initial sampling: 14671540
# 20:29:49 - INFO - Number of points after Poisson Disk Sampling: 689733
# 20:29:50 - INFO - Saving cloud as .las format...
# 20:29:51 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/1_wall.las
# 20:29:51 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/1_wall.pth in .pth format.
# 20:29:51 - INFO - Number of points after initial sampling: 1498477
# 20:29:52 - INFO - Number of points after Poisson Disk Sampling: 248692
# 20:29:52 - INFO - Saving cloud as .las format...
# 20:29:52 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/2_floor.las
# 20:29:52 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/2_floor.pth in .pth format.
# 20:29:52 - INFO - Number of points after initial sampling: 370428
# 20:29:53 - INFO - Number of points after Poisson Disk Sampling: 79385
# 20:29:53 - INFO - Saving cloud as .las format...
# 20:29:53 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/3_roof.las
# 20:29:53 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/3_roof.pth in .pth format.
# 20:29:53 - INFO - Number of points after initial sampling: 3188965
# 20:29:55 - INFO - Number of points after Poisson Disk Sampling: 263540
# 20:29:55 - INFO - Saving cloud as .las format...
# 20:29:55 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/4_ceiling.las
# 20:29:55 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/4_ceiling.pth in .pth format.
# 20:29:55 - INFO - Number of points after initial sampling: 517887
# 20:29:56 - INFO - Number of points after Poisson Disk Sampling: 149229
# 20:29:56 - INFO - Saving cloud as .las format...
# 20:29:56 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/5_footpath.las
# 20:29:56 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/5_footpath.pth in .pth format.
# 20:29:56 - INFO - Number of points after initial sampling: 109805
# 20:29:56 - INFO - Number of points after Poisson Disk Sampling: 15337
# 20:29:56 - INFO - Saving cloud as .las format...
# 20:29:56 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/6_grass.las
# 20:29:56 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/6_grass.pth in .pth format.
# 20:29:56 - INFO - Number of points after initial sampling: 552463
# 20:29:56 - INFO - Number of points after Poisson Disk Sampling: 63553
# 20:29:56 - INFO - Saving cloud as .las format...
# 20:29:56 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/7_column.las
# 20:29:57 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/7_column.pth in .pth format.
# 20:29:57 - INFO - Number of points after initial sampling: 414210
# 20:29:57 - INFO - Number of points after Poisson Disk Sampling: 21694
# 20:29:57 - INFO - Saving cloud as .las format...
# 20:29:57 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/8_door.las
# 20:29:57 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/8_door.pth in .pth format.
# 20:29:57 - INFO - Number of points after initial sampling: 810548
# 20:29:57 - INFO - Number of points after Poisson Disk Sampling: 33125
# 20:29:57 - INFO - Saving cloud as .las format...
# 20:29:57 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/9_window.las
# 20:29:57 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/9_window.pth in .pth format.
# 20:29:57 - INFO - Number of points after initial sampling: 444757
# 20:29:57 - INFO - Number of points after Poisson Disk Sampling: 10380
# 20:29:57 - INFO - Saving cloud as .las format...
# 20:29:57 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/10_stair.las
# 20:29:57 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/10_stair.pth in .pth format.
# 20:29:58 - INFO - Number of points after initial sampling: 441408
# 20:29:58 - INFO - Number of points after Poisson Disk Sampling: 14141
# 20:29:58 - INFO - Saving cloud as .las format...
# 20:29:58 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/11_railing.las
# 20:29:58 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/11_railing.pth in .pth format.
# 20:29:58 - INFO - Number of points after initial sampling: 56847
# 20:29:58 - INFO - Number of points after Poisson Disk Sampling: 1732
# 20:29:58 - INFO - Saving cloud as .las format...
# 20:29:58 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/12_rwp.las
# 20:29:58 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/12_rwp.pth in .pth format.
# 20:29:58 - INFO - Number of points after initial sampling: 147315
# 20:29:58 - INFO - Number of points after Poisson Disk Sampling: 8590
# 20:29:58 - INFO - Saving cloud as .las format...
# 20:29:58 - INFO - Saved as: ../data/clouds/res0.05_pr0.049/park_row/eval/13_other.las
# 20:29:58 - INFO - Saved point cloud to ../data/clouds/res0.05_pr0.049/park_row/eval/13_other.pth in .pth format.
# 20:29:58 - INFO - Combined LAS file saved to ../data/clouds/res0.05_pr0.049/park_row/eval/combined.las with 1599131 points.
# 20:29:59 - INFO - Combined data saved to ../data/clouds/res0.05_pr0.049/park_row/eval/combined.pth
